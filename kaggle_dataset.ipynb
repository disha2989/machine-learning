# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv("data.csv")

# %%
data
# Out:
#      sky air temp humidity    wind water forecast enjoy sport
# 0  sunny     warm   normal  strong  warm     same         yes
# 1  sunny     warm     high  strong  warm     same         yes
# 2  rainy     cold     high  strong  warm   change          no
# 3  sunny     warm     high  strong  cool   change         yes

# %%
a=np.array(data)
a
# Out:
# array([['sunny', 'warm', 'normal', 'strong', 'warm', 'same', 'yes'],
#        ['sunny', 'warm', 'high', 'strong', 'warm', 'same', 'yes'],
#        ['rainy', 'cold', 'high', 'strong', 'warm', 'change', 'no'],
#        ['sunny', 'warm', 'high', 'strong', 'cool', 'change', 'yes']],
#       dtype=object)

# %%
data2=pd.read_csv("output.csv")
data2
# Out:
#       Unnamed: 0       Entity Code  Year  Self-harm  \
# 0              0  Afghanistan  AFG  1990   0.305874
# 1              1  Afghanistan  AFG  1991   0.312853
# 2              2  Afghanistan  AFG  1992   0.328217
# 3              3  Afghanistan  AFG  1993   0.332590
# 4              4  Afghanistan  AFG  1994   0.324567
# 5              5  Afghanistan  AFG  1995   0.329530
# 6              6  Afghanistan  AFG  1996   0.336002
# 7              7  Afghanistan  AFG  1997   0.335071
# 8              8  Afghanistan  AFG  1998   0.320792
# 9              9  Afghanistan  AFG  1999   0.341697
# 10            10  Afghanistan  AFG  2000   0.348693
# 11            11  Afghanistan  AFG  2001   0.361598
# 12            12  Afghanistan  AFG  2002   0.363507
# 13            13  Afghanistan  AFG  2003   0.387140
# 14            14  Afghanistan  AFG  2004   0.407697
# 15            15  Afghanistan  AFG  2005   0.415972
# 16            16  Afghanistan  AFG  2006   0.420402
# ...

# %%
b=np.array(data2)
b
# Out:
# array([[0, 'Afghanistan', 'AFG', ..., 0.12130190641045001,
#         2.37583129525598, 0.6464586749376899],
#        [1, 'Afghanistan', 'AFG', ..., 0.12343549113315999,
#         2.35323011050052, 0.6260811727016501],
#        [2, 'Afghanistan', 'AFG', ..., 0.14624170428622, 2.42095341080174,
#         0.5984761329076099],
#        ...,
#        [8007, 'Zimbabwe', 'ZWE', ..., 19.765750611741673,
#         2.1599939249191897, 1.05462971286026],
#        [8008, 'Zimbabwe', 'ZWE', ..., 18.053551276460468,
#         2.26284287739674, 1.10387445558377],
#        [8009, 'Zimbabwe', 'ZWE', ..., 16.95829969323207,
#         2.23018007609968, 1.13048767489723]], dtype=object)
